# %%
tasks=[]

def addtask():
    task=input('Please enter a task: ')
    tasks.append(task)
    print(f'Task {task} added to the list.')
    
def listtasks():
    if not tasks:
        print(f'There are no tasks currently.')
    else:
        print('Current tasks: ')
        for index,task in enumerate(tasks):
            print(f'Task #{index}. {task}')
                  
def deletetask():
    listtasks()
    try:
        tasktodelete= int(input('Enter the # to delete: '))
        if tasktodelete >= 0 and tasktodelete < len(tasks):
            tasks.pop(tasktodelete)
            print(f'Task #{tasktodelete} has been removed.')
        else:
            print(f'Task #{tasktodelete} was not found.')
    except:
        print('Invalid Input.')
   
print('Welcome to the to do list app :)')

while True :
    print('\n')
    print('Please select one of the following options >>')
    print('---------------------------------------------')
    print('1. Add new Tasks')
    print('2. Delte tasks')
    print('3. List tasks')
    print('4. Quit')
    
    choice = input("Enter your choice >> ")
    if (choice=='1'):
        addtask()
    elif(choice=='2'):
        deletetask()
    elif(choice=='3'):
        listtasks()
    elif(choice=='4'):
        break
    else:
        print('Invalid input. Please try again.')
print('Goodbye :) ')
# Out:
# Welcome to the to do list app :)
#
#
# Please select one of the following options >>
# ---------------------------------------------
# 1. Add new Tasks
# 2. Delte tasks
# 3. List tasks
# 4. Quit
# Enter your choice >> 1
# Please enter a task: go to store
# Task go to store added to the list.
#
#
# Please select one of the following options >>
# ---------------------------------------------
# 1. Add new Tasks
# 2. Delte tasks
# 3. List tasks
# 4. Quit
# Enter your choice >> 3
# Current tasks:
# Task #0. go to store
#
#
# Please select one of the following options >>
# ---------------------------------------------
# 1. Add new Tasks
# 2. Delte tasks
# 3. List tasks
# 4. Quit
# Enter your choice >> 2
# Current tasks:
# Task #0. go to store
# Enter the # to delete: 0
# Task #0 has been removed.
#
#
# Please select one of the following options >>
# ---------------------------------------------
# 1. Add new Tasks
# 2. Delte tasks
# 3. List tasks
# 4. Quit
# Enter your choice >> 4
# Goodbye :)
